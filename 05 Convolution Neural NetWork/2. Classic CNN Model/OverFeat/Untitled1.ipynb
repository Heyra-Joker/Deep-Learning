# %%
from PIL import Image,ImageDraw
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/Users/huwang/Joker/Data_Set/VOCdevkit/VOC2012/JPEGImages/2007_000027.jpg'

# %%
img = Image.open(path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=486x500 at 0x113F65048>

# %%
draw = ImageDraw.Draw(img)
draw.rectangle([(174, 101), (349, 351)],outline='red')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=486x500 at 0x113F65048>

# %%
img.size
# Out:
# (486, 500)

# %%
486 / 221
# Out:
# 2.1990950226244346

# %%
500 / 221
# Out:
# 2.262443438914027

# %%
img = Image.open(path)
img2 = img.resize((221,221))
draw2 = ImageDraw.Draw(img2)
draw2.rectangle([(174/2.199, 101/2.26), (349/2.199, 351/2.26)],outline='red')
img2
# Out:
# <PIL.Image.Image image mode=RGB size=221x221 at 0x114044E48>

# %%
plt.imread(path)
# Out:
# array([[[208, 220, 210],
#         [206, 218, 208],
#         [203, 215, 205],
#         ...,
#         [ 84,  54,  88],
#         [ 65,  41,  67],
#         [184, 164, 175]],
#
#        [[210, 222, 210],
#         [209, 221, 209],
#         [208, 220, 210],
#         ...,
#         [ 91,  70,  67],
#         [ 97,  77,  76],
#         [190, 175, 172]],
#
#        [[209, 221, 209],
#         [211, 223, 211],
#         [211, 221, 210],
#         ...,
#         [133, 115,  79],
#         [136, 121,  92],
#         [202, 190, 176]],
#
#        ...,
#
#        [[156,  97,  89],
#         [153,  95,  84],
#         [144,  87,  78],
#         ...,
#         [ 47,  32,  53],
#         [ 64,  53,  69],
#         [240, 232, 243]],
#
#        [[155,  96,  88],
#         [154,  96,  85],
#         [146,  92,  82],
#         ...,
#         [ 52,  37,  58],
#         [ 66,  55,  71],
#         [238, 230, 241]],
#
#        [[154,  95,  87],
#         [155,  99,  86],
#         [147,  93,  81],
# ...

# %%
import tensorflow as tf

# %%
a = np.array([[1,0],
 [1,0],
 [1,0],
 [1,0]])

a
# Out:
# array([[1, 0],
#        [1, 0],
#        [1, 0],
#        [1, 0]])

# %%
b = np.array([[1,1],
 [1,0],
 [1,1],
 [1,0]])
b
# Out:
# array([[1, 1],
#        [1, 0],
#        [1, 1],
#        [1, 0]])

# %%
np.equal(a,b)
# Out:
# array([[ True, False],
#        [ True,  True],
#        [ True, False],
#        [ True,  True]])

# %%
np.equal(a,b).all(axis=1)
# Out:
# array([False,  True, False,  True])
